# %% [markdown]
# c![34.png](attachment:34.png)

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ![56.png](attachment:56.png)

# %% [markdown]
# # Creating a Dataframe

# %%
yr={"years":[24,32,44,12]}
pd.DataFrame(yr)
# Out:
#    years
# 0     24
# 1     32
# 2     44
# 3     12

# %%
names={'name':['john','james','Alice','peter'],
       "years":[24,32,44,12]}
pd.DataFrame(names)
# Out:
#     name  years
# 0   john     24
# 1  james     32
# 2  Alice     44
# 3  peter     12

# %%
# series
places={"towns":['kisumu','mombasa','nairobi','kitale','nakuru']}
s_places=pd.DataFrame(places)
s_places
# Out:
#      towns
# 0   kisumu
# 1  mombasa
# 2  nairobi
# 3   kitale
# 4   nakuru

# %%
athletes= {"name": ["nic juma","dan kaya", "ann mbugua","liz timisi","vic keera"],
          "age":[22,18,25,20,23],
          "gender":["male", "male","female","female","male"]}

df_athletes=pd.DataFrame(athletes)
df_athletes
# Out:
#          name  age  gender
# 0    nic juma   22    male
# 1    dan kaya   18    male
# 2  ann mbugua   25  female
# 3  liz timisi   20  female
# 4   vic keera   23    male

# %%
df_athletes.head(2)
# Out:
#        name  age gender
# 0  nic juma   22   male
# 1  dan kaya   18   male

# %%
df_athletes.tail(2)
# Out:
#          name  age  gender
# 3  liz timisi   20  female
# 4   vic keera   23    male

# %% [markdown]
# ## Reading and writing tabular data

# %%
# Reading in a CSV file:
# df=pd.read_csv('file location')

# Reading html
df=pd.read_html('https://en.wikipedia.org/wiki/Counties_of_Kenya')[2]
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File ~\anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# inst

# %%
pip install PyMysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
conn=pymysql.connect(host='127.0.0.1',
                    port=3306,
                    user='root',
                    password='',
                    db='sql_invoicing',
                    charset='utf8mb4')

# %%
cursor= conn.cursor()

# %%
sqlquerry='SELECT * FROM admin LIMIT'

# %%
cursor.execute(sqlquerry)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 cursor.execute(sqlquerry)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# ...

# %%
emp=cursor.fetchall()

# %%
len(emp)
# Out:
# 0

# %%
pd.read_sql('employees')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
# ----> 1 pd.read_sql('employees')
#
# TypeError: read_sql() missing 1 required positional argument: 'con'

# %%
pip install mysql-connector-python

# %%
import mysql.connector

db=mysql.connector.connect(host="127.0.0.1", user="root", password="",database="employees")

cursor=db.cursor()

cursor.execute("SELECT * FROM employees LIMIT 10")

# for table_name in cursor:
#    print(table_name)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:268, in CMySQLConnection._open_connection(self)
#     267 try:
# --> 268     self._cmysql.connect(**cnx_kwargs)
#     269     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown database 'employees'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [60], in <cell line: 3>()
#       1 import mysql.connector
# ----> 3 db=mysql.connector.connect(host="127.0.0.1", user="root", password="",database="employees")
#       5 cursor=db.cursor()
#       7 cursor.execute("SELECT * FROM employees LIMIT 10")
#
# File ~\anaconda3\lib\site-packages\mysql\connector\pooling.py:286, in connect(*args, **kwargs)
# ...

# %%
r=cursor.fetchall()
pd.DataFrame(r,columns=['ID','Birth Date','FName','LName','Gender','Hire Date'])
# Out:
#       ID  Birth Date      FName      LName Gender   Hire Date
# 0  10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1  10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2  10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3  10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4  10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5  10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6  10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7  10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8  10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9  10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %%
pd.read_sql()

# %% [raw]
# df2=pd.read_sql('D:\New folder (2)')
#  #df head(5)

# %%
# converting to csv
df_athletes.to_csv('atheletes_csv')
#converting to json
df_athletes.to_json('atheltes_json')
df_athletes
# Out:
#   name  age  gender
# 0  nic   22    male
# 1  dan   18    male
# 2  ann   25  female
# 3  liz   20  female
# 4  vic   23    male

# %% [markdown]
# # DATA MANIPULATION

# %% [markdown]
# ## Selecting subset of a table (DATA MANIPULATION)
# * Selecting and filtering specific rows/columns
# * Filtering data on a condition
# * Methods for slicing, selecting and extracting data that you need

# %% [markdown]
# ### Accessing individual columns

# %%
df_athletes
# Out:
#          name  age  gender
# 0    nic juma   22    male
# 1    dan kaya   18    male
# 2  ann mbugua   25  female
# 3  liz timisi   20  female
# 4   vic keera   23    male

# %%
df_athletes.gender
# Out:
# 0      male
# 1      male
# 2    female
# 3    female
# 4      male
# Name: gender, dtype: object

# %%
df_athletes['age']
# Its good when you have a column more than one word
# Out:
# 0    22
# 1    18
# 2    25
# 3    20
# 4    23
# Name: age, dtype: int64

# %%
df_athletes[['name','age']]
# Out:
#          name  age
# 0    nic juma   22
# 1    dan kaya   18
# 2  ann mbugua   25
# 3  liz timisi   20
# 4   vic keera   23

# %%
# df_athletes[df_athletes['name']=='ann']
df_athletes.query('name=="ann"')
# Out:
#   name  age  gender
# 2  ann   25  female

# %%
day= input('What is today? ')
if day=='sunday':
    print("True")
else:
    print('not true')
# Out:
# What is today? sunday
# True

# %%
name=input("what's your name? ")
age=int(input("how old are you? "))
if len(name)>6 and age>18:
    print(f'my name id {name} and am {age} year old')
else: 
    print('Not sure')
# Out:
# what's your name? zsxfgchvnb
# how old are you? 23
# my name id zsxfgchvnb and am 23 year old

# %%
df_athletes.gender
# Out:
# 0      male
# 1      male
# 2    female
# 3    female
# 4      male
# Name: gender, dtype: object

# %%
df_athletes['gender']
# Out:
# 0      male
# 1      male
# 2    female
# 3    female
# 4      male
# Name: gender, dtype: object

# %%
df_athletes[['gender','age']]
# Out:
#    gender  age
# 0    male   22
# 1    male   18
# 2  female   25
# 3  female   20
# 4    male   23

# %%
type(df_athletes[['gender','age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Accesing individual rows
# * loc-positions
# * iloc-index

# %%
df_athletes
# Out:
#   name  age  gender
# 0  nic   22    male
# 1  dan   18    male
# 2  ann   25  female
# 3  liz   20  female
# 4  vic   23    male

# %%
df_athletes.iloc[1]
# Out:
# name       dan
# age         18
# gender    male
# Name: 1, dtype: object

# %%
df_athletes.iloc[1:4]
# Out:
#   name  age  gender
# 1  dan   18    male
# 2  ann   25  female
# 3  liz   20  female

# %% [markdown]
# ###### Accesing specific column

# %%
df_athletes.iloc[3,1]
# Out:
# 20

# %%
df_athletes.iloc[0:2,0:2]
# Out:
#   name  age
# 0  nic   22
# 1  dan   18

# %%
df_athletes
# Out:
#   name  age  gender
# 0  nic   22    male
# 1  dan   18    male
# 2  ann   25  female
# 3  liz   20  female
# 4  vic   23    male

# %%
df_athletes.gender== 'female'
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: gender, dtype: bool

# %%
df_athletes.query('gender=="female"')
# Out:
#   name  age  gender
# 2  ann   25  female
# 3  liz   20  female

# %%
df_athletes[df_athletes.gender== 'female']
# Out:
#   name  age  gender
# 2  ann   25  female
# 3  liz   20  female

# %%
df_athletes.query('age>20 & gender=="male"')
# Out:
#   name  age gender
# 0  nic   22   male
# 4  vic   23   male

# %%
df_athletes[(df_athletes.age>20) & (df_athletes.gender== 'female')]
# Out:
#   name  age  gender
# 2  ann   25  female

# %%
df_athletes.query('age>20 & gender == "female"')
# Out:
#   name  age  gender
# 2  ann   25  female

# %% [markdown]
# # Data summary
# * Getting summary statistics for columns with numerical data
# * **describe** method gives us overview of numeric columns

# %%
df_athletes.describe()
# Out:
#              age
# count   5.000000
# mean   21.600000
# std     2.701851
# min    18.000000
# 25%    20.000000
# 50%    22.000000
# 75%    23.000000
# max    25.000000

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   gender  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df_athletes.columns
# Out:
# Index(['name', 'age', 'gender'], dtype='object')

# %%
df.read_excel()

# %%
df=pd.read_csv('nashville.csv')
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   SalePrice        56477 non-null  object
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.describe()
# Out:
#           UniqueID        Acreage     LandValue  BuildingValue    TotalValue  \
# count  56477.000000  26015.000000  2.601500e+04   2.601500e+04  2.601500e+04
# mean   28334.001133      0.498923  6.906856e+04   1.607847e+05  2.323754e+05
# std    16352.590651      1.570454  1.060401e+05   2.067999e+05  2.810643e+05
# min        0.000000      0.010000  1.000000e+02   0.000000e+00  1.000000e+02
# 25%    14186.000000      0.180000  2.100000e+04   7.590000e+04  1.028000e+05
# 50%    28313.000000      0.270000  2.880000e+04   1.114000e+05  1.485000e+05
# 75%    42513.000000      0.450000  6.000000e+04   1.807000e+05  2.683500e+05
# max    56635.000000    160.060000  2.772000e+06   1.297180e+07  1.394040e+07
#
#           YearBuilt      Bedrooms      FullBath      HalfBath
# count  24163.000000  24157.000000  24275.000000  24144.000000
# mean    1963.744899      3.089912      1.886014      0.283921
# std       26.542982      0.852869      0.961515      0.487881
# ...

# %%
df['Acreage'].head()
# Out:
# 0    2.3
# 1    3.5
# 2    2.9
# 3    2.6
# 4    2.0
# Name: Acreage, dtype: float64

# %%
df[['SalePrice','OwnerName','Acreage','Bedrooms']].head()
# Out:
#   SalePrice                           OwnerName  Acreage  Bedrooms
# 0    240000           FRAZIER, CYRENTHA LYNETTE      2.3       3.0
# 1    366000             BONER, CHARLES & LESLIE      3.5       3.0
# 2    435000           WILSON, JAMES E. & JOANNE      2.9       4.0
# 3    255000            BAKER, JAY K. & SUSAN E.      2.6       3.0
# 4    278000  POST, CHRISTOPHER M. & SAMANTHA C.      2.0       4.0

# %%
df_vacantAbove30=df.query("SoldAsVacant=='Yes' & Acreage>30")
df_vacantAbove30
# Out:
#        UniqueID          ParcelID                  LandUse  \
# 5361       31272  061 00 0 055.00                   FOREST
# 11727      35211  076 01 0 083.00  VACANT RESIDENTIAL LAND
# 24165      36420  102 00 0 018.00                   FOREST
# 35356      24782  128 00 0 181.00  VACANT RESIDENTIAL LAND
# 40139      29943  138 00 0 024.00                GREENBELT
# 49083       4974  163 00 0 122.00          VACANT RES LAND
#
#                      PropertyAddress           SaleDate SalePrice  \
# 5361           0  HART LN, NASHVILLE       May 26, 2015   1500000
# 11727     0  LEBANON PIKE, HERMITAGE      July 31, 2015   1450000
# 24165   0  CHARLOTTE PIKE, NASHVILLE     August 6, 2015   5200000
# 35356    OLD HICKORY BLVD, NASHVILLE  December 24, 2014    500000
# 40139  0  COUCHVILLE PIKE, HERMITAGE      April 3, 2015     78000
# 49083            0  BELL RD, ANTIOCH      June 28, 2013    580000
#
#          LegalReference SoldAsVacant                          OwnerName  \
# ...

# %%
df_vacantAbove30.count()
# Out:
# UniqueID           6
# ParcelID           6
# LandUse            6
# PropertyAddress    6
# SaleDate           6
# SalePrice          6
# LegalReference     6
# SoldAsVacant       6
# OwnerName          6
# OwnerAddress       6
# Acreage            6
# TaxDistrict        6
# LandValue          6
# BuildingValue      6
# TotalValue         6
# YearBuilt          0
# Bedrooms           0
# FullBath           1
# HalfBath           1
# dtype: int64

# %% [markdown]
# ###### Checking any missing Values
#
# * isna
# * isnull
# * **isany** - It returns true if there is any missing value and false if there is no  missing values

# %%
df.isnull().any()
# Out:
# UniqueID           False
# ParcelID           False
# LandUse            False
# PropertyAddress     True
# SaleDate           False
# SalePrice          False
# LegalReference     False
# SoldAsVacant       False
# OwnerName           True
# OwnerAddress        True
# Acreage             True
# TaxDistrict         True
# LandValue           True
# BuildingValue       True
# TotalValue          True
# YearBuilt           True
# Bedrooms            True
# FullBath            True
# HalfBath            True
# dtype: bool

# %%
df['SoldAsVacant'].isnull().any()
# Out:
# False

# %%
df.iloc[12:24,3:8]
# Out:
#                        PropertyAddress           SaleDate SalePrice  \
# 12     1900  TINNIN RD, GOODLETTSVILLE      July 13, 2015    190000
# 13   629  GAYLEMORE DR, GOODLETTSVILLE       June 7, 2013    189900
# 14   633  GAYLEMORE DR, GOODLETTSVILLE      June 30, 2014    157500
# 15   637  GAYLEMORE DR, GOODLETTSVILLE      June 30, 2014    247400
# 16      1976 SADIE  LN, GOODLETTSVILLE      July 15, 2016    211500
# 17   644  GAYLEMORE DR, GOODLETTSVILLE     March 31, 2015    185900
# 18   1921  NORMERLE DR, GOODLETTSVILLE   October 11, 2013    349900
# 19   1916  NORMERLE DR, GOODLETTSVILLE      June 28, 2013    192500
# 20  2050  GRACELAND DR, GOODLETTSVILLE  February 10, 2015    279900
# 21  2034  GRACELAND DR, GOODLETTSVILLE     April 14, 2016    379900
# 22      811  BENTON CT, GOODLETTSVILLE       July 8, 2013    192500
# 23  331  VIEW RIDGE DR, GOODLETTSVILLE    August 31, 2015    193500
#
#       LegalReference SoldAsVacant
# 12  20150717-0069947           No
# ...

# %%
df.iloc[[2,4,633, 45, 845],[2,6,7,11]]
# Out:
#            LandUse    LegalReference SoldAsVacant                TaxDistrict
# 2    SINGLE FAMILY  20160927-0101718           No  GENERAL SERVICES DISTRICT
# 4    SINGLE FAMILY  20141015-0095255           No  GENERAL SERVICES DISTRICT
# 633  SINGLE FAMILY  20141028-0099249           No  GENERAL SERVICES DISTRICT
# 45   SINGLE FAMILY  20160413-0035454           No  GENERAL SERVICES DISTRICT
# 845  SINGLE FAMILY  20130905-0093821           No  GENERAL SERVICES DISTRICT

# %%
df.loc[[2,4,633, 45, 845],['SalePrice','OwnerName','Acreage','Bedrooms']]
# Out:
#     SalePrice                           OwnerName  Acreage  Bedrooms
# 2      435000           WILSON, JAMES E. & JOANNE     2.90       4.0
# 4      278000  POST, CHRISTOPHER M. & SAMANTHA C.     2.00       4.0
# 633    164000        HOYE, JONATHAN B. & JOANN V.     0.94       3.0
# 45     169900                     DISMANG, JEREMY     0.98       3.0
# 845    129900             ESTRADA, WALTER CATALAN     0.96       3.0

# %% [markdown]
# ##### Looking for rows with empty columns

# %%
df_empty=df.loc[df.isnull().any(axis=1)].head()
df_empty
# Out:
#     UniqueID           ParcelID            LandUse  \
# 10      29467  007 14 0A 024.00      SINGLE FAMILY
# 11      10754  007 14 0A 027.00      SINGLE FAMILY
# 12      34751  007 14 0B 010.00  RESIDENTIAL CONDO
# 25      48716  011 15 0A 004.00      SINGLE FAMILY
# 56       4514   018 00 0 087.00  VACANT RURAL LAND
#
#                          PropertyAddress           SaleDate SalePrice  \
# 10        2209  KAYLA DR, GOODLETTSVILLE     April 14, 2015    425000
# 11   109  BAILEY VIEW CT, GOODLETTSVILLE  December 12, 2013    585000
# 12       1900  TINNIN RD, GOODLETTSVILLE      July 13, 2015    190000
# 25      119 LAKESIDE  DR, GOODLETTSVILLE       May 31, 2016    435000
# 56  0  BRICK CHURCH PIKE, GOODLETTSVILLE      June 28, 2013    250000
#
#       LegalReference SoldAsVacant                        OwnerName  \
# 10  20150415-0033442           No                              NaN
# 11  20131227-0130352           No                              NaN
# ...

# %%
df_athletes
# Out:
#          name  age  gender
# 0    nic juma   22    male
# 1    dan kaya   18    male
# 2  ann mbugua   25  female
# 3  liz timisi   20  female
# 4   vic keera   23    male

# %%
df_athletes['sport']=['basketball','rugby','tennis','badminton','judo']
df_athletes
# Out:
#          name  age  gender       sport
# 0    nic juma   22    male  basketball
# 1    dan kaya   18    male       rugby
# 2  ann mbugua   25  female      tennis
# 3  liz timisi   20  female   badminton
# 4   vic keera   23    male        judo

# %%
df_athletes['first_name']=df_athletes['name'].apply(lambda  x: x.split(' ')[0])
df_athletes['last_ name']=df_athletes['name'].apply(lambda  x: x.split(' ')[-1])
df_athletes['Age-5']=df_athletes['age'].apply(lambda  x:x-5)

#df_athletes['age-5']=df_athletes['age']-5
df_athletes
# Out:
#          name  age  gender       sport first_name last_ name  Age-5  age-5
# 0    nic juma   22    male  basketball        nic       juma     17     17
# 1    dan kaya   18    male       rugby        dan       kaya     13     13
# 2  ann mbugua   25  female      tennis        ann     mbugua     20     20
# 3  liz timisi   20  female   badminton        liz     timisi     15     15
# 4   vic keera   23    male        judo        vic      keera     18     18

# %% [markdown]
# ###### Dropping a column

# %%
df_athletes.pop('age-5')
# Out:
# 0    17
# 1    13
# 2    20
# 3    15
# 4    18
# Name: age-5, dtype: int64

# %%
df_athletes
# Out:
#          name  age  gender       sport first_name last_ name  Age-5
# 0    nic juma   22    male  basketball        nic       juma     17
# 1    dan kaya   18    male       rugby        dan       kaya     13
# 2  ann mbugua   25  female      tennis        ann     mbugua     20
# 3  liz timisi   20  female   badminton        liz     timisi     15
# 4   vic keera   23    male        judo        vic      keera     18

# %% [markdown]
# ##### Renaming a column

# %%
df_athletes.rename(columns={'sport':'sporting_activity'},inplace=True)
df_athletes
# Out:
#          name  age  gender sporting_activity first_name last_ name  Age-5
# 0    nic juma   22    male        basketball        nic       juma     17
# 1    dan kaya   18    male             rugby        dan       kaya     13
# 2  ann mbugua   25  female            tennis        ann     mbugua     20
# 3  liz timisi   20  female         badminton        liz     timisi     15
# 4   vic keera   23    male              judo        vic      keera     18

# %%
df_athletes.describe()
# Out:
#              age      Age-5
# count   5.000000   5.000000
# mean   21.600000  16.600000
# std     2.701851   2.701851
# min    18.000000  13.000000
# 25%    20.000000  15.000000
# 50%    22.000000  17.000000
# 75%    23.000000  18.000000
# max    25.000000  20.000000

# %%
df_athletes['age'].mean()
# Out:
# 21.6

# %%
df_athletes['age'].nuniqueque()
# Out:
# 5

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %% [markdown]
# #### Map Method
# * E.g intead of male, female, we use 1,0

# %%
df['SoldAsVacant']=df['SoldAsVacant'].map({'Yes':1,'No':0})
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress            SaleDate SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
#
#      LegalReference  SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           NaN           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           NaN             BONER, CHARLES & LESLIE
# ...

# %%
df_athletes
# Out:
#          name  age  gender sporting_activity first_name last_ name  Age-5
# 0    nic juma   22    male        basketball        nic       juma     17
# 1    dan kaya   18    male             rugby        dan       kaya     13
# 2  ann mbugua   25  female            tennis        ann     mbugua     20
# 3  liz timisi   20  female         badminton        liz     timisi     15
# 4   vic keera   23    male              judo        vic      keera     18

# %%
df_athletes['gender']=df_athletes['gender'].map({'male':1, 'female':0})
df_athletes
# Out:
#          name  age  gender sporting_activity first_name last_ name  Age-5
# 0    nic juma   22       1        basketball        nic       juma     17
# 1    dan kaya   18       1             rugby        dan       kaya     13
# 2  ann mbugua   25       0            tennis        ann     mbugua     20
# 3  liz timisi   20       0         badminton        liz     timisi     15
# 4   vic keera   23       1              judo        vic      keera     18

# %%
df_athletes['age'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_athletes.sort_values(by='age')
# Out:
#          name  age  gender sporting_activity first_name last_ name  Age-5
# 1    dan kaya   18       1             rugby        dan       kaya     13
# 3  liz timisi   20       0         badminton        liz     timisi     15
# 0    nic juma   22       1        basketball        nic       juma     17
# 4   vic keera   23       1              judo        vic      keera     18
# 2  ann mbugua   25       0            tennis        ann     mbugua     20

# %%
df_athletes.sort_values(by='age', ascending=False)
# Out:
#          name  age  gender sporting_activity first_name last_ name  Age-5
# 2  ann mbugua   25       0            tennis        ann     mbugua     20
# 4   vic keera   23       1              judo        vic      keera     18
# 0    nic juma   22       1        basketball        nic       juma     17
# 3  liz timisi   20       0         badminton        liz     timisi     15
# 1    dan kaya   18       1             rugby        dan       kaya     13
